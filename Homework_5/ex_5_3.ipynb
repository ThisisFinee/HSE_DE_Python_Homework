# %% [markdown]
# ## Задание 3

# %%
from checking_account import CheckingAccount
from savings_account import SavingsAccount
from account import Account

# %% [markdown]
# #### Демонстрация работы CheckingAccount

# %%
Account._account_counter = 100001 # Ради чистоты эксперимента
checking = CheckingAccount("Иван Иванов", 1000)

checking.load_transactions_from_file('transactions_dirty.csv')
print(f"Баланс расчетного счета после загрузки: {checking.get_balance()}")

Account._account_counter = 100003 # Ради чистоты эксперимента
checking_1 = CheckingAccount("Иван Иванов", 1000)

checking_1.load_transactions_from_file('transactions_dirty.json')
print(f"Баланс расчетного счета после загрузки: {checking_1.get_balance()}")
# Out:
# Загружено 18 транзакций из 26
# Баланс расчетного счета после загрузки: 7431.0
# Загружено 13 транзакций из 21
# Баланс расчетного счета после загрузки: 4634.0

# %% [markdown]
# #### Демонстрация работы SavingsAccount

# %%
Account._account_counter = 100002 # Ради чистоты эксперимента
savings = SavingsAccount("Иван Иванов", 1000)

savings.load_transactions_from_file('transactions_dirty.csv')
print(f"Баланс сберегательного счета после загрузки: {savings.get_balance()}")

Account._account_counter = 100004 # Ради чистоты эксперимента
savings_1 = SavingsAccount("Иван Иванов", 1000)
savings_1.load_transactions_from_file('transactions_dirty.json')
print(f"Баланс сберегательного счета после загрузки: {savings_1.get_balance()}")
# Out:
# Загружено 19 транзакций из 27
# Баланс сберегательного счета после загрузки: 5241.27
# Загружено 20 транзакций из 31
# Баланс сберегательного счета после загрузки: 4247.0

# %% [markdown]
# #### Графики

# %%
checking.plot_history()
checking_1.plot_history()
savings.plot_history()
savings_1.plot_history()
